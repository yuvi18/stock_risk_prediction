# %%
# Import Libraries
import pandas as pd
import numpy as np
import operator
import sys
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from sklearn.decomposition import PCA
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
import matplotlib.patches as mpatches
import seaborn as sns
import plotly
import plotly.express as px

# %%
# Companies description
desc_df = pd.read_csv('../notebooks/content/constituents.csv')
print('\nCompanies Details')
print(desc_df.head())

# stocks details
stocks_df = pd.read_csv('../notebooks/content/stocks_data/all_stocks_5yr.csv')#, parse_dates=['date'])
print('\nCompanies Stocks')
print(stocks_df.head())
# Out:
# Companies Details
#   Symbol                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology
#
# Companies Stocks
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
# dicitonary for companies name and sector
companies_names = {symbol:name for symbol, name in desc_df[['Symbol', 'Name']].values}
companies_sector = {symbol:sector for symbol, sector in desc_df[['Symbol', 'Sector']].values}

# get all companies symbols
symbols = stocks_df['Name'].values
dates = set(stocks_df['date'].values)
dates = sorted(dates)

# store each individual date and all it's stocks
dates_dictionary = {date:{} for date in dates}

# %%
wv = KeyedVectors.load("wordvectors.kv", mmap='r')
wv['REGN']
# Out:
# array([-2.7622976 ,  1.7772101 ,  2.4447286 ,  0.31753993], dtype=float32)

# %%
binary_vectors = 'stoack2vec_Keyed_Binary.bin'
text_vectors = 'stoack2vec_Keyed_Text.vec'

model = KeyedVectors.load_word2vec_format(text_vectors, binary=False)
word_dict = {}
embeddings = []
for word in model.vocab:
    word_dict[word] = model[word]
    #embeddings.append(model2[word])

for key in word_dict:
    embeddings.append(word_dict[key])
#embeddings
len(word_dict)
# Out:
# 505

# %%
word_dict["REGN"]
# Out:
# array([-2.7622976 ,  1.7772101 ,  2.4447286 ,  0.31753993], dtype=float32)

# %%
# Load Vectors

binary_vectors = 'stoack2vec_Keyed_Binary.bin'
text_vectors = 'stoack2vec_Keyed_Text.vec'

model = KeyedVectors.load_word2vec_format(binary_vectors, binary=True)
word_dict = {}
for word in model.vocab:
    word_dict[word] = model[word]
#save_pkl(word_dict, out_path, overwrite=True) 
model

# %%
words = list(model.wv.vocab)
X = model[model.wv.vocab]
X
# Out:
# <ipython-input-11-6be01e7da47b>:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   words = list(model.wv.vocab)
# <ipython-input-11-6be01e7da47b>:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   X = model[model.wv.vocab]
# array([[ 0.21071582, -0.7017758 , -0.25024316, -1.5931607 ],
#        [-1.2621394 ,  1.0335326 , -0.2911443 , -0.04010985],
#        [-0.61622965, -0.651401  , -0.4577913 , -1.1594683 ],
#        ...,
#        [-0.4990332 ,  0.83009595,  0.54597   , -0.62710524],
#        [-0.28532436,  0.3711571 ,  0.10531114, -0.8866491 ],
#        [-0.37769213,  0.4182406 ,  0.08199602, -0.8473123 ]],
#       dtype=float32)

# %%
words = list(model.wv.vocab)
X = model[model.wv.vocab]


pca = PCA(n_components=4)

result = pca.fit_transform(X)

sectors = ['Industrials' ,'Health Care' ,'Information Technology' ,'Utilities','Financials','Materials', 
                     'Consumer Discretionary','Real Estate', 'Consumer Staples','Energy',
                     'Telecommunication Services']
# Out:
# <ipython-input-12-9f26541f58c6>:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   words = list(model.wv.vocab)
# <ipython-input-12-9f26541f58c6>:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   X = model[model.wv.vocab]

# %%
target_symb = 'ALXN'

print('Symbol:%s\tName:%s\tSector: %s'%(target_symb, companies_names[target_symb], companies_sector[target_symb]))
top_similar = model.similar_by_word(target_symb, topn=20)
#top_similar = model.similar_by_vector(target_symb, topn=20)
print('Most Similar')
for similar in top_similar:
  symb = similar[0]
  name = companies_names[symb]
  sect = companies_sector[symb]
  print('Symbol: %s\tName: %s\t\t\tSector: %s'%(symb, name, sect))
# Out:
# Symbol:ALXN	Name:Alexion Pharmaceuticals	Sector: Health Care
# Most Similar
# Symbol: REGN	Name: Regeneron			Sector: Health Care
# Symbol: VRTX	Name: Vertex Pharmaceuticals Inc			Sector: Health Care
# Symbol: NFLX	Name: Netflix Inc.			Sector: Information Technology
# Symbol: AAL	Name: American Airlines Group			Sector: Industrials
# Symbol: UAA	Name: Under Armour Class A			Sector: Consumer Discretionary
# Symbol: ILMN	Name: Illumina Inc			Sector: Health Care
# Symbol: CNC	Name: Centene Corporation			Sector: Health Care
# Symbol: CELG	Name: Celgene Corp.			Sector: Health Care
# Symbol: QRVO	Name: Qorvo			Sector: Information Technology
# Symbol: INCY	Name: Incyte			Sector: Health Care
# Symbol: MU	Name: Micron Technology			Sector: Information Technology
# Symbol: ALK	Name: Alaska Air Group Inc			Sector: Industrials
# Symbol: LEN	Name: Lennar Corp.			Sector: Consumer Discretionary
# Symbol: UAL	Name: United Continental Holdings			Sector: Industrials
# Symbol: DHI	Name: D. R. Horton			Sector: Consumer Discretionary
# Symbol: NVDA	Name: Nvidia Corporation			Sector: Information Technology
# Symbol: BIIB	Name: Biogen Inc.			Sector: Health Care
# Symbol: TRIP	Name: TripAdvisor			Sector: Consumer Discretionary
# Symbol: AGN	Name: Allergan, Plc			Sector: Health Care
# Symbol: MYL	Name: Mylan N.V.			Sector: Health Care

# %%
newWordToken
# Out:
# '%APTV%'

# %%
sectors = ['Industrials' ,'Health Care' ,'Information Technology' ,'Utilities','Financials','Materials', 
                     'Consumer Discretionary','Real Estate', 'Consumer Staples','Energy',
                     'Telecommunication Services']

newResultX = []
newResultY = []
newWords = list()
newWordToken = ""
with open('../notebooks/content/stocks.txt') as stockFile:
    contents = stockFile.read()
    for i in range(0,505):
        newWordToken = "%" + words[i] + "%"
        if newWordToken in contents:
            newWords.append(words[i])
            newResultX.append(result[i,0])
            newResultY.append(result[i,1])
#Increase Size of Figure
pyplot.figure(num=None, figsize=(20, 14), dpi=80, facecolor='w', edgecolor='k')
#Colors
sector_color_dict = {'Industrials':'red','Health Care':'orange','Information Technology':'yellow','Utilities':'green',
                     'Financials':'blue','Materials':'purple','Consumer Discretionary':'cyan','Real Estate':'magenta',
                     'Consumer Staples':'pink','Energy':'brown','Telecommunication Services':'gray'}
cvec = [sector_color_dict[companies_sector[word]] for word in newWords]

# create a scatter plot of the projection
pyplot.scatter(newResultX[:], newResultY[:], c = cvec)
#Names the Labels
for i, word in enumerate(newWords):
    pyplot.annotate(companies_names[word], xy=(newResultX[i], newResultY[i]), fontsize = 12)
#Legend
red_patch=mpatches.Patch(color='red', label='Industrials')
orange_patch=mpatches.Patch(color='orange', label='Health Care')
yellow_patch=mpatches.Patch(color='yellow', label='Information Technology')
green_patch=mpatches.Patch(color='green', label='Utilities')
blue_patch=mpatches.Patch(color='blue', label='Financials')
purple_patch=mpatches.Patch(color='purple', label='Materials')
cyan_patch=mpatches.Patch(color='cyan', label='Consumer Discretionary')
magenta_patch=mpatches.Patch(color='magenta', label='Real Estate')
pink_patch=mpatches.Patch(color='pink', label='Consumer Staples')
brown_patch=mpatches.Patch(color='brown', label='Energy')
gray_patch=mpatches.Patch(color='gray', label='Telecommunication Services')
pyplot.legend(handles=[red_patch,orange_patch,yellow_patch,green_patch,blue_patch,purple_patch,cyan_patch,magenta_patch,
                       pink_patch,brown_patch,gray_patch],loc='best')
pyplot.show()

# %%
pca.fit(X)
eigen_vecs = pca.components_
eigen_vals = pca.explained_variance_
print(eigen_vals)
# Make a list of (eigenvalue, eigenvector) tuples
eigen_pairs = [(np.abs(eigen_vals[i]), eigen_vecs[:, i]) for i in range(len(eigen_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eigen_pairs.sort(key=lambda k: k[0], reverse=True)

w = np.hstack((eigen_pairs[0][1][:, np.newaxis], eigen_pairs[1][1][:, np.newaxis]))

print('Matrix W:\n', w)
# Out:
# [2.8311336e+00 1.5937755e+00 4.4174448e-01 1.3167919e-03]
# Matrix W:
#  [[-0.30050397  0.26717305]
#  [-0.07494922  0.8092084 ]
#  [ 0.8834503   0.32326612]
#  [-0.35156143  0.41145995]]

# %%
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [2.8311336e+00 1.5937755e+00 4.4174448e-01 1.3167919e-03]
# [5.8158398e-01 3.2740042e-01 9.0745099e-02 2.7050122e-04]
# [0.581584  0.9089844 0.9997295 1.       ]

# %%
variance_exp_cumsum = pca.explained_variance_ratio_.cumsum()
fig, axes = pyplot.subplots(1,1,figsize=(16,7), dpi=100)
pyplot.plot(variance_exp_cumsum, color='firebrick')
pyplot.title('Scree Plot of Variance Explained %', fontsize=22)
pyplot.xlabel('Number of Components', fontsize=16)
pyplot.ylabel('cumulative explained variance', fontsize=16)
pyplot.show()

# %%
top_similar = model.similar_by_word(target_symb, topn=5)
top_similar
# Out:
# [('REGN', 0.9995741844177246),
#  ('VRTX', 0.9995722770690918),
#  ('NFLX', 0.9967755079269409),
#  ('AAL', 0.9959300756454468),
#  ('UAA', 0.9950464367866516)]

# %%
dimensions = []
similars = []
data = {}
positions = ["first", "second", "third", "fourth"]
index = 0
for similar in top_similar:
  symb = similar[0]
  name = companies_names[symb]
  dimensions.append(symb)
  #similar = companies_sector[symb]
  similar = similar[1]
  similars.append(similar)
  data[symb] = word_dict[symb][0:4]
  data["position"] = positions
  index += 1

# %%
pd.DataFrame.from_dict(data)
# Out:
#        REGN position      VRTX      NFLX       AAL       UAA
# 0 -2.762298    first -3.001144 -2.183543 -2.915684 -2.082068
# 1  1.777210   second  1.675097  1.283443  1.346438  1.255567
# 2  2.444729    third  2.582419  1.830117  2.351257  1.906496
# 3  0.317540   fourth  0.332063  0.001985  0.209244 -0.035915

# %%
df = pd.DataFrame.from_dict(data)
features = dimensions

fig = px.scatter_matrix(
    df,
    dimensions=features,
    color="position"
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <div>                            <div id="d426d9f6-c26c-4bb3-9d96-8bdc9c44d2bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d426d9f6-c26c-4bb3-9d96-8bdc9c44d2bd")) {                    Plotly.newPlot(                        "d426d9f6-c26c-4bb3-9d96-8bdc9c44d2bd",                        [{"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "REGN", "values": [-2.7622976303100586]}, {"axis": {"matches": true}, "label": "VRTX", "values": [-3.0011441707611084]}, {"axis": {"matches": true}, "label": "NFLX", "values": [-2.1835432052612305]}, {"axis": {"matches": true}, "label": "AAL", "values": [-2.915684461593628]}, {"axis": {"matches": true}, "label": "UAA", "values": [-2.0820679664611816]}], "hovertemplate": "position=first<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "first", "marker": {"color": "#636efa", "symbol": "circle"}, "name": "first", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "REGN", "values": [1.7772101163864136]}, {"axis": {"matches": true}, "label": "VRTX", "values": [1.6750973463058472]}, {"axis": {"matches": true}, "label": "NFLX", "values": [1.2834433317184448]}, {"axis": {"matches": true}, "label": "AAL", "values": [1.3464381694793701]}, {"axis": {"matches": true}, "label": "UAA", "values": [1.2555674314498901]}], "hovertemplate": "position=second<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "second", "marker": {"color": "#EF553B", "symbol": "circle"}, "name": "second", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "REGN", "values": [2.4447286128997803]}, {"axis": {"matches": true}, "label": "VRTX", "values": [2.582418918609619]}, {"axis": {"matches": true}, "label": "NFLX", "values": [1.8301167488098145]}, {"axis": {"matches": true}, "label": "AAL", "values": [2.3512566089630127]}, {"axis": {"matches": true}, "label": "UAA", "values": [1.9064955711364746]}], "hovertemplate": "position=third<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "third", "marker": {"color": "#00cc96", "symbol": "circle"}, "name": "third", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "REGN", "values": [0.31753993034362793]}, {"axis": {"matches": true}, "label": "VRTX", "values": [0.3320629298686981]}, {"axis": {"matches": true}, "label": "NFLX", "values": [0.001984944799914956]}, {"axis": {"matches": true}, "label": "AAL", "values": [0.20924405753612518]}, {"axis": {"matches": true}, "label": "UAA", "values": [-0.03591473773121834]}], "hovertemplate": "position=fourth<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "fourth", "marker": {"color": "#ab63fa", "symbol": "circle"}, "name": "fourth", "showlegend": true, "type": "splom"}],                        {"dragmode": "select", "legend": {"title": {"text": "position"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks":  ...

# %%
pca = PCA()
components = pca.fit_transform(X)
#pca = PCA(n_components=4)

#result = pca.fit_transform(X)
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(4),
    color=words
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <div>                            <div id="9901b96f-036a-4c9c-bbef-7bec9f6f76b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9901b96f-036a-4c9c-bbef-7bec9f6f76b6")) {                    Plotly.newPlot(                        "9901b96f-036a-4c9c-bbef-7bec9f6f76b6",                        [{"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [-0.6247785091400146]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [-1.336381435394287]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [0.27941885590553284]}, {"axis": {"matches": true}, "label": "PC 4 (0.0%)", "values": [0.008145465515553951]}], "hovertemplate": "color=MCO<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "MCO", "marker": {"color": "#636efa", "symbol": "circle"}, "name": "MCO", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [0.3774416148662567]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [0.9586899280548096]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [-0.8697108626365662]}, {"axis": {"matches": true}, "label": "PC 4 (0.0%)", "values": [-0.03602394461631775]}], "hovertemplate": "color=MNST<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "MNST", "marker": {"color": "#EF553B", "symbol": "circle"}, "name": "MNST", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [-0.5147980451583862]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [-0.9552061557769775]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [-0.5923398733139038]}, {"axis": {"matches": true}, "label": "PC 4 (0.0%)", "values": [-0.00558813801035285]}], "hovertemplate": "color=SPGI<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "SPGI", "marker": {"color": "#00cc96", "symbol": "circle"}, "name": "SPGI", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [1.0483335256576538]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [-0.38629934191703796]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [-0.18334342539310455]}, {"axis": {"matches": true}, "label": "PC 4 (0.0%)", "values": [-0.03391522169113159]}], "hovertemplate": "color=JNPR<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "JNPR", "marker": {"color": "#ab63fa", "symbol": "circle"}, "name": "JNPR", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [3.388056993484497]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [0.6441238522529602]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [-1.710334300994873]}, {"axis": {"matches": true}, "label": "PC 4 (0.0%)", "values": [0.04865741729736328]}], "hovertemplate": "color=AAL<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>", "legendgroup": "AAL", "marker": {"color": "#FFA15A", "symbol": "circle"}, "name": "AAL", "showlegend": true, "type": "splom"}, {"diagonal": {"visible": false}, "dimensions": [{"axis": {"matches": true}, "label": "PC 1 (58.2%)", "values": [2.483259439468384]}, {"axis": {"matches": true}, "label": "PC 2 (32.7%)", "values": [0.24780695140361786]}, {"axis": {"matches": true}, "label": "PC 3 (9.1%)", "values": [-0.4924566447734833]}, {"axis": {"matches": true}, "label": "PC  ...

# %%
pca = PCA()
components = pca.fit_transform(X)
total_var = pca.explained_variance_ratio_.sum() * 100

fig = px.scatter_3d(
    components, x=0, y=1, z=2, color=words,
    title=f'Total Explained Variance: {total_var:.2f}%',
    labels={'0': 'PC 1', '1': 'PC 2', '2': 'PC 3'}
)
fig.show()
# Out:
# <div>                            <div id="4a1ca02a-b726-45e2-a750-96d4a1bcf69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a1ca02a-b726-45e2-a750-96d4a1bcf69f")) {                    Plotly.newPlot(                        "4a1ca02a-b726-45e2-a750-96d4a1bcf69f",                        [{"hovertemplate": "color=MCO<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "MCO", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "MCO", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.6247785091400146], "y": [-1.336381435394287], "z": [0.27941885590553284]}, {"hovertemplate": "color=MNST<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "MNST", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "MNST", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [0.3774416148662567], "y": [0.9586899280548096], "z": [-0.8697108626365662]}, {"hovertemplate": "color=SPGI<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "SPGI", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "SPGI", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.5147980451583862], "y": [-0.9552061557769775], "z": [-0.5923398733139038]}, {"hovertemplate": "color=JNPR<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "JNPR", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "JNPR", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.0483335256576538], "y": [-0.38629934191703796], "z": [-0.18334342539310455]}, {"hovertemplate": "color=AAL<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "AAL", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "AAL", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [3.388056993484497], "y": [0.6441238522529602], "z": [-1.710334300994873]}, {"hovertemplate": "color=BBY<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "BBY", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "BBY", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [2.483259439468384], "y": [0.24780695140361786], "z": [-0.4924566447734833]}, {"hovertemplate": "color=INTU<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "INTU", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "INTU", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1.0721089839935303], "y": [-0.9218366146087646], "z": [-0.11896532028913498]}, {"hovertemplate": "color=SRCL<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "SRCL", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "SRCL", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1.162476897239685], "y": [0.2269362360239029], "z": [0.6287015676498413]}, {"hovertemplate": "color=SCHW<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "SCHW", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "SCHW", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.8906779289245605], "y": [-2.1593518257141113], "z": [-0.4732462167739868]}, {"hovertemplate": "color=MCHP<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legendgroup": "MCHP", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "MCHP", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [0.6966474652290344], "y": [-0.639005184173584], "z": [-0.5106287598609924]}, {"hovertemplate": "color=FLR<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>", "legen ...

# %%
pca = PCA()
components = pca.fit_transform(X)
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

fig =px.area(
    x=range(1, exp_var_cumul.shape[0] + 1),
    y=exp_var_cumul,
    labels={"x": "Number of Components", "y": "Cumulative Explained Variance"}
)
fig.update_xaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
fig.update_layout( title={'text':"Scree Plot of Variance Explained %",
                         'y':0.95,
                         'yanchor': 'top',
                         'x':0.5,
                         'xanchor': 'center'})
fig.show()
# Out:
# <div>                            <div id="8620413e-c50c-4144-a556-a045d124c0d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8620413e-c50c-4144-a556-a045d124c0d6")) {                    Plotly.newPlot(                        "8620413e-c50c-4144-a556-a045d124c0d6",                        [{"hovertemplate": "Number of Components=%{x}<br>Cumulative Explained Variance=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": [1, 2, 3, 4], "xaxis": "x", "y": [0.5815839767456055, 0.9089844226837158, 0.9997295141220093, 1.0], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": ...

# %%
dimensions = []
similars = []
data = {}
positions = ["first", "second", "third", "fourth"]
index = 0
for similar in top_similar:
  symb = similar[0]
  name = companies_names[symb]
  dimensions.append(symb)
  #similar = companies_sector[symb]
  similar = similar[1]
  similars.append(similar)
  data[symb] = word_dict[symb][0:4]
  data["position"] = positions
  index += 1

# %%
full_data = desc_df

# %%
sector_color_dict = {'Industrials':'red','Health Care':'orange','Information Technology':'yellow','Utilities':'green',
                     'Financials':'blue','Materials':'purple','Consumer Discretionary':'cyan','Real Estate':'magenta',
                     'Consumer Staples':'pink','Energy':'brown','Telecommunication Services':'gray'}

# %%
full_data = desc_df

full_data["Vector1"] = 0.0
full_data["Vector2"] = 0.0
full_data["Vector3"] = 0.0
full_data["Vector4"] = 0.0
full_data["Sector_Color"] = ""

#for index, word in enumerate(words):
for word in words:
    row_word = word_dict[word]
    index = full_data[full_data.Symbol == word].index[0]
    sector = full_data.iloc[index,2]
    full_data['Vector1'][index] = round(row_word[0],4)
    full_data['Vector2'][index] = round(row_word[1],4)
    full_data['Vector3'][index] = round(row_word[2],4)
    full_data['Vector4'][index] = round(row_word[3],4)
    full_data["Sector_Color"][index] = sector_color_dict[sector]
# Out:
# <ipython-input-602-53951f665649>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-602-53951f665649>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-602-53951f665649>:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-602-53951f665649>:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-602-53951f665649>:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
full_data.dtypes
# Out:
# Symbol           object
# Name             object
# Sector           object
# Vector1         float64
# Vector2         float64
# Vector3         float64
# Vector4         float64
# Sector_Color     object
# dtype: object

# %%
full_data.head()
# Out:
#   Symbol                 Name                  Sector  Vector1  Vector2  \
# 0    MMM           3M Company             Industrials   0.6798  -1.1998
# 1    AOS      A.O. Smith Corp             Industrials  -0.3775  -0.7172
# 2    ABT  Abbott Laboratories             Health Care  -0.2295  -0.4520
# 3   ABBV          AbbVie Inc.             Health Care  -1.5866   0.4775
# 4    ACN        Accenture plc  Information Technology   0.6027  -0.9136
#
#    Vector3  Vector4 Sector_Color
# 0  -2.1786  -1.7342          red
# 1  -0.1041  -1.3757          red
# 2  -0.9809  -1.1382       orange
# 3  -0.0043  -0.2662       orange
# 4  -1.1869  -1.7206       yellow

# %%
target_symb = 'ALXN'

#print('Symbol:%s\tName:%s\tSector: %s'%(target_symb, companies_names[target_symb], companies_sector[target_symb]))
top_similars = model.similar_by_word(target_symb, topn=20)
#top_similar = model.similar_by_vector(target_symb, topn=20)
print('Most Similar')
similars = []
for similar in top_similars:
    symb = similar[0]
    similars.append(symb)
    name = companies_names[symb]
    sect = companies_sector[symb]
    #print('Symbol: %s\tName: %s\t\t\tSector: %s'%(symb, name, sect))
# Out:
# Most Similar

# %%
def top_similars(symbol, top_number):
    similars = []
    top_similars = model.similar_by_word(symbol, topn=top_number)
    for similar in top_similars:
        #symb = similar[0]
        similars.append(similar[0])
    return similars

# %%
def top_similars_by_symbols(symbols, top_number):
    similars = []
    top_similars = model.most_similar(symbols, topn=top_number)
    for similar in top_similars:
        #symb = similar[0]
        similars.append(similar[0])
    return similars

# %%
similar_companies = full_data[full_data['Symbol'].isin(top_similars('ALXN', 20))]
similar_companies
# Out:
#     Symbol                         Name                  Sector  Vector1  \
# 17     ALK         Alaska Air Group Inc             Industrials  -2.4104
# 23     AGN                Allergan, Plc             Health Care  -1.7822
# 32     AAL      American Airlines Group             Industrials  -2.9157
# 72    BIIB                  Biogen Inc.             Health Care  -2.2454
# 96    CELG                Celgene Corp.             Health Care  -1.9421
# 97     CNC          Centene Corporation             Health Care  -1.9372
# 137    DHI                 D. R. Horton  Consumer Discretionary  -1.5095
# 244   ILMN                 Illumina Inc             Health Care  -2.3383
# 245   INCY                       Incyte             Health Care  -2.8345
# 280    LEN                 Lennar Corp.  Consumer Discretionary  -1.6195
# 310     MU            Micron Technology  Information Technology  -2.6879
# 321    MYL                   Mylan N.V.             Health Care  -1.5672
# 326   NFLX                 Netflix Inc.  Information Technology  -2.1835
# 344   NVDA           Nvidia Corporation  Information Technology  -1.4880
# 382   QRVO                        Qorvo  Information Technology  -1.9715
# 392   REGN                    Regeneron             Health Care  -2.7623
# 451   TRIP                  TripAdvisor  Consumer Discretionary  -1.7851
# 458    UAA         Under Armour Class A  Consumer Discretionary  -2.0821
# 461    UAL  United Continental Holdings             Industrials  -3.1626
# 475   VRTX   Vertex Pharmaceuticals Inc             Health Care  -3.0011
#
#      Vector2  Vector3  Vector4 Sector_Color
# 17    0.9645   1.4879   0.0189          red
# 23    1.0603   0.9580  -0.0743       orange
# 32    1.3464   2.3513   0.2092          red
# 72    0.9176   1.3235  -0.0556       orange
# 96    1.1830   1.1876  -0.0027       orange
# 97    1.0164   1.3054  -0.0930       orange
# 137   1.0446   1.3221  -0.2562         cyan
# 244   1.3651   1.4638   0.1760       orange
# 245   2.6315   3.1634   0.5880       orange
# 280   0.9887   1.1978  -0.2106         cyan
# 310   1.8034   3.2863   0.1088       yellow
# 321   1.6106   1.6400  -0.0249       orange
# 326   1.2834   1.8301   0.0020       yellow
# 344   1.1342   1.2831  -0.2283       yellow
# 382   1.3459   2.1752  -0.1533       yellow
# 392   1.7772   2.4447   0.3175       orange
# 451   1.4387   2.2335  -0.1367         cyan
# 458   1.2556   1.9065  -0.0359         cyan
# 461   1.0107   2.3227   0.1444          red
# 475   1.6751   2.5824   0.3321       orange

# %%
full_data.dtypes
# Out:
# Symbol           object
# Name             object
# Sector           object
# Vector1         float64
# Vector2         float64
# Vector3         float64
# Vector4         float64
# Sector_Color     object
# dtype: object

# %%
company_name = full_data[full_data.Symbol == "ALXN"]
company_name.iloc[0,1]
# Out:
# 'Alexion Pharmaceuticals'

# %%
similar_companies = full_data[full_data['Symbol'].isin(top_similars('AAPL', 20))]
df = similar_companies
company_name = full_data[full_data.Symbol == "AAPL"].iloc[0,1]
fig = px.scatter(df, x=df.Vector1, 
                 y=df.Vector2, 
                 color=df.Sector, 
                 text=df.Name,
                 size=abs(df.Vector3.astype(float)))

fig.update_traces(textposition='top center', textfont_size=8)
#fig.update_traces(texttemplate='%{text:.2s}', textposition='top center')
fig.update_xaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
fig.update_layout( title={'text':f"Top 20 Similar Companies to {company_name}",
                         'y':0.95,
                         'yanchor': 'top',
                         'x':0.4,
                         'xanchor': 'center'})
fig.update_layout(
    legend=dict(
        #traceorder="reversed",
        #title_font_family="Times New Roman",
        font=dict(
            family="Courier",
            size=12,
            color="black"
        ),
        #bgcolor="LightSteelBlue",
        #bordercolor="Black",
        #borderwidth=1
    )
)


fig.show()
# Out:
# <div>                            <div id="c4ea7273-39f9-4183-b7f6-60d2a1c8c100" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4ea7273-39f9-4183-b7f6-60d2a1c8c100")) {                    Plotly.newPlot(                        "c4ea7273-39f9-4183-b7f6-60d2a1c8c100",                        [{"hovertemplate": "Sector=Information Technology<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Information Technology", "marker": {"color": "#636efa", "size": [0.19110000133514404, 0.0013000000035390258, 0.24310000240802765, 0.24860000610351562, 0.4562000036239624], "sizemode": "area", "sizeref": 0.0013899999856948854, "symbol": "circle"}, "mode": "markers+text", "name": "Information Technology", "orientation": "v", "showlegend": true, "text": ["Adobe Systems Inc", "Cognizant Technology Solutions", "Global Payments Inc.", "KLA-Tencor Corp.", "Verisign Inc."], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-1.1022000312805176, -0.8855000138282776, -0.7785999774932861, -1.0426000356674194, -0.7178000211715698], "xaxis": "x", "y": [-0.32409998774528503, -0.23090000450611115, 0.18219999969005585, 0.17800000309944153, 0.07959999889135361], "yaxis": "y"}, {"hovertemplate": "Sector=Health Care<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Health Care", "marker": {"color": "#EF553B", "size": [0.11559999734163284, 0.1738000065088272, 0.1784999966621399, 0.09260000288486481, 0.47940000891685486, 0.09260000288486481, 0.15369999408721924, 0.02419999986886978, 0.2517000138759613, 0.3091999888420105, 0.23659999668598175, 0.28790000081062317, 0.11259999871253967], "sizemode": "area", "sizeref": 0.0013899999856948854, "symbol": "circle"}, "mode": "markers+text", "name": "Health Care", "orientation": "v", "showlegend": true, "text": ["Aetna Inc", "Amgen Inc", "Anthem Inc.", "Boston Scientific", "Bristol-Myers Squibb", "Cerner", "Express Scripts", "Hologic", "Intuitive Surgical Inc.", "McKesson Corp.", "ResMed", "The Cooper Companies", "Zoetis"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.5512999892234802, -1.2539000511169434, -0.8187000155448914, -1.3421000242233276, -0.7979000210762024, -0.8526999950408936, -0.4514999985694885, -1.1243000030517578, -1.0930999517440796, -0.8098999857902527, -0.7361000180244446, -0.9059000015258789, -0.9498000144958496], "xaxis": "x", "y": [0.24529999494552612, -0.0738999992609024, 0.3086000084877014, 0.12790000438690186, 0.1137000024318695, 0.1339000016450882, 0.243599995970726, 0.15880000591278076, 0.10760000348091125, 0.3012999892234802, 0.4424999952316284, 0.29420000314712524, 0.48980000615119934], "yaxis": "y"}, {"hovertemplate": "Sector=Consumer Discretionary<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Consumer Discretionary", "marker": {"color": "#00cc96", "size": [0.42809998989105225], "sizemode": "area", "sizeref": 0.0013899999856948854, "symbol": "circle"}, "mode": "markers+text", "name": "Consumer Discretionary", "orientation": "v", "showlegend": true, "text": ["Darden Restaurants"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.5609999895095825], "xaxis": "x", "y": [0.4867999851703644], "yaxis": "y"}, {"hovertemplate": "Sector=Industrials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Industrials", "marker": {"color": "#ab63fa", "size": [0.5559999942779541], "sizemode": "area", "sizeref": 0.0013899999856948854, "symbol": "circle"}, "mode": "markers+text", "name": "Industrials", "orientation": "v", "showlegend": true, "text": ["IHS Markit Ltd. ...

# %%
def similar_to_company(symbol, top_number):
    similar_companies = full_data[full_data['Symbol'].isin(top_similars(symbol, top_number))]
    df = similar_companies
    company_name = full_data[full_data.Symbol == symbol].iloc[0,1]
    fig = px.scatter(df, x=df.Vector1, 
                     y=df.Vector2, 
                     color=df.Sector, 
                     text=df.Name,
                     size=abs(df.Vector3.astype(float)))

    fig.update_traces(textposition='top center', textfont_size=8)
    #fig.update_traces(texttemplate='%{text:.2s}', textposition='top center')
    fig.update_xaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
    fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
    fig.update_layout( title={'text':f"Top {top_number} Similar Companies to {company_name}",
                             'y':0.95,
                             'yanchor': 'top',
                             'x':0.4,
                             'xanchor': 'center'})
    fig.update_layout(
        legend=dict(
            #traceorder="reversed",
            #title_font_family="Times New Roman",
            font=dict(
                family="Courier",
                size=12,
                color="black"
            ),
            #bgcolor="LightSteelBlue",
            #bordercolor="Black",
            #borderwidth=1
        )
    )
    fig.show()

# %%
top_ten_symbols = ['AAPL', 'MSFT', 'AMZN', 'FB', 'GOOGL', 'GOOG', 'BRK.B', 'JNJ', 'V', 'PG']

# %%
similar_to_company("GOOG", 20)
# Out:
# <div>                            <div id="f92fc7bb-8787-4177-9d0c-e7227bcc6229" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f92fc7bb-8787-4177-9d0c-e7227bcc6229")) {                    Plotly.newPlot(                        "f92fc7bb-8787-4177-9d0c-e7227bcc6229",                        [{"hovertemplate": "Sector=Industrials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Industrials", "marker": {"color": "#636efa", "size": [0.10409999638795853, 0.6712999939918518], "sizemode": "area", "sizeref": 0.0020827500522136687, "symbol": "circle"}, "mode": "markers+text", "name": "Industrials", "orientation": "v", "showlegend": true, "text": ["A.O. Smith Corp", "Boeing Company"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.3774999976158142, -0.2614000141620636], "xaxis": "x", "y": [-0.717199981212616, -0.49129998683929443], "yaxis": "y"}, {"hovertemplate": "Sector=Materials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Materials", "marker": {"color": "#EF553B", "size": [0.8320000171661377], "sizemode": "area", "sizeref": 0.0020827500522136687, "symbol": "circle"}, "mode": "markers+text", "name": "Materials", "orientation": "v", "showlegend": true, "text": ["Air Products & Chemicals Inc"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.07419999688863754], "xaxis": "x", "y": [-0.6567999720573425], "yaxis": "y"}, {"hovertemplate": "Sector=Information Technology<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Information Technology", "marker": {"color": "#00cc96", "size": [0.6674000024795532, 0.6328999996185303, 0.7519999742507935, 0.8331000208854675, 0.7200000286102295, 0.08309999853372574], "sizemode": "area", "sizeref": 0.0020827500522136687, "symbol": "circle"}, "mode": "markers+text", "name": "Information Technology", "orientation": "v", "showlegend": true, "text": ["Alphabet Inc Class A", "CA, Inc.", "Gartner Inc", "Microsoft Corp.", "Total System Services", "Western Union Co"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.6506999731063843, -0.32100000977516174, -0.36660000681877136, -0.45590001344680786, -0.10989999771118164, -0.621999979019165], "xaxis": "x", "y": [-0.580299973487854, -0.5616999864578247, -0.33970001339912415, -0.5407000184059143, -0.5680999755859375, -0.5667999982833862], "yaxis": "y"}, {"hovertemplate": "Sector=Financials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Financials", "marker": {"color": "#ab63fa", "size": [0.21130000054836273, 0.1770000010728836, 0.11649999767541885, 0.572700023651123, 0.27230000495910645, 0.4578000009059906, 0.4016999900341034], "sizemode": "area", "sizeref": 0.0020827500522136687, "symbol": "circle"}, "mode": "markers+text", "name": "Financials", "orientation": "v", "showlegend": true, "text": ["BlackRock", "CBOE Holdings", "CME Group Inc.", "Intercontinental Exchange", "JPMorgan Chase & Co.", "S&P Global, Inc.", "T. Rowe Price Group"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.32710000872612, -0.7742999792098999, -0.5209000110626221, -0.44670000672340393, -0.19750000536441803, -0.6161999702453613, 0.026799999177455902], "xaxis": "x", "y": [-1.0972000360488892, -0.30320000648498535, -0.44020000100135803, -0.23389999568462372, -1.8516000509262085, -0.6514000296592712, -1.243299961090088], "yaxis": "y"}, {"hovertemplate": "Sector=Health Care<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Health Care", "marker": {"co ...

# %%
model.most_similar_to_given("INCY", top_ten_symbols)
# Out:
# 'FB'

# %%
def most_similars(symbols, top_number):
    similar_companies = full_data[full_data['Symbol'].isin(top_similars_by_symbols(symbols, top_number))]
    df = similar_companies
    #company_name = full_data[full_data.Symbol == symbol].iloc[0,1]
    fig = px.scatter(df, x=df.Vector1, 
                     y=df.Vector2, 
                     color=df.Sector, 
                     text=df.Name,
                     size=abs(df.Vector3.astype(float)))

    fig.update_traces(textposition='top center', textfont_size=8)
    #fig.update_traces(texttemplate='%{text:.2s}', textposition='top center')
    fig.update_xaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
    fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'),showgrid=False)
    fig.update_layout( title={'text':f"Companes similar to Top {top_number} S&P Companiesto",
                             'y':0.95,
                             'yanchor': 'top',
                             'x':0.4,
                             'xanchor': 'center'})
    fig.update_layout(
        legend=dict(
            #traceorder="reversed",
            #title_font_family="Times New Roman",
            font=dict(
                family="Courier",
                size=12,
                color="black"
            ),
            #bgcolor="LightSteelBlue",
            #bordercolor="Black",
            #borderwidth=1
        )
    )
    fig.show()

# %%
model.most_similar(top_ten_symbols)
# Out:
# [('ICE', 0.9943976998329163),
#  ('IT', 0.9914363622665405),
#  ('YUM', 0.9874942302703857),
#  ('UNH', 0.9693443179130554),
#  ('MTD', 0.9680495262145996),
#  ('SBUX', 0.9675626754760742),
#  ('ABT', 0.9645333290100098),
#  ('BA', 0.9627834558486938),
#  ('NDAQ', 0.960785984992981),
#  ('ANSS', 0.9605118036270142)]

# %%
most_similars_list = top_similars_by_symbols(top_ten_symbols, 10)
most_similars(most_similars_list, 10)
# Out:
# <div>                            <div id="f6f4fd97-afea-428b-ba2c-d28f8b99885d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6f4fd97-afea-428b-ba2c-d28f8b99885d")) {                    Plotly.newPlot(                        "f6f4fd97-afea-428b-ba2c-d28f8b99885d",                        [{"hovertemplate": "Sector=Materials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Materials", "marker": {"color": "#636efa", "size": [0.8320000171661377], "sizemode": "area", "sizeref": 0.0032545000314712523, "symbol": "circle"}, "mode": "markers+text", "name": "Materials", "orientation": "v", "showlegend": true, "text": ["Air Products & Chemicals Inc"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.07419999688863754], "xaxis": "x", "y": [-0.6567999720573425], "yaxis": "y"}, {"hovertemplate": "Sector=Information Technology<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Information Technology", "marker": {"color": "#EF553B", "size": [0.6674000024795532, 0.553600013256073, 0.8741000294685364, 0.8331000208854675, 1.301800012588501, 0.7200000286102295, 1.1194000244140625], "sizemode": "area", "sizeref": 0.0032545000314712523, "symbol": "circle"}, "mode": "markers+text", "name": "Information Technology", "orientation": "v", "showlegend": true, "text": ["Alphabet Inc Class A", "Cisco Systems", "Intuit Inc.", "Microsoft Corp.", "Oracle Corp.", "Total System Services", "Visa Inc."], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.6506999731063843, 0.1429000049829483, -0.03840000182390213, -0.45590001344680786, 0.08479999750852585, -0.10989999771118164, -0.03539999946951866], "xaxis": "x", "y": [-0.580299973487854, -0.3061000108718872, -0.6140000224113464, -0.5407000184059143, -0.5896000266075134, -0.5680999755859375, -0.7172999978065491], "yaxis": "y"}, {"hovertemplate": "Sector=Industrials<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Industrials", "marker": {"color": "#00cc96", "size": [0.9315999746322632], "sizemode": "area", "sizeref": 0.0032545000314712523, "symbol": "circle"}, "mode": "markers+text", "name": "Industrials", "orientation": "v", "showlegend": true, "text": ["Equifax Inc."], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [0.14959999918937683], "xaxis": "x", "y": [-0.4876999855041504], "yaxis": "y"}, {"hovertemplate": "Sector=Health Care<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendgroup": "Health Care", "marker": {"color": "#ab63fa", "size": [1.1086000204086304, 1.1898000240325928, 1.2825000286102295, 0.6851999759674072, 1.2574000358581543, 0.644599974155426, 0.7633000016212463], "sizemode": "area", "sizeref": 0.0032545000314712523, "symbol": "circle"}, "mode": "markers+text", "name": "Health Care", "orientation": "v", "showlegend": true, "text": ["Henry Schein", "Laboratory Corp. of America Holding", "Medtronic plc", "Thermo Fisher Scientific", "Varian Medical Systems", "Waters Corporation", "Zimmer Biomet Holdings"], "textfont": {"size": 8}, "textposition": "top center", "type": "scatter", "x": [-0.0502999983727932, -0.03480000048875809, -0.04639999940991402, -0.25459998846054077, -0.06629999727010727, -0.24580000340938568, -0.033900000154972076], "xaxis": "x", "y": [-0.34549999237060547, -0.3944000005722046, -0.30300000309944153, -0.8424000144004822, -0.29760000109672546, -0.784500002861023, -0.47999998927116394], "yaxis": "y"}, {"hovertemplate": "Sector=Consumer Discretionary<br>Vector1=%{x}<br>Vector2=%{y}<br>size=%{marker.size}<br>Name=%{text}<extra></extra>", "legendg ...

# %%
model.most_similar(top_ten_symbols, topn=10)
# Out:
# [('ICE', 0.9943976998329163),
#  ('IT', 0.9914363622665405),
#  ('YUM', 0.9874942302703857),
#  ('UNH', 0.9693443179130554),
#  ('MTD', 0.9680495262145996),
#  ('SBUX', 0.9675626754760742),
#  ('ABT', 0.9645333290100098),
#  ('BA', 0.9627834558486938),
#  ('NDAQ', 0.960785984992981),
#  ('ANSS', 0.9605118036270142)]
